# %% [markdown]
# # Comparisons
#
# Some plots visualize a transformation of the original data set. Use a stat parameter to choose a common transformation to visualize.
#
# Each stat creates additional variables to map aesthetics to. These variables use a common ..name.. syntax.
#
# Look at the examples below.

# %%
import pandas as pd

from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="XYMSHo"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.0.4/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/mpg.csv')

# %%
p = ggplot(df, aes('class', 'hwy'))
p1 = p + geom_boxplot(aes(color='class'), show_legend=False) + \
         scale_color_brewer(type='qual', palette='Dark2') + \
         ggtitle('geom_boxplot(): stat="boxplot" (default)')
p2 = p + geom_crossbar(aes(color='class'), stat='boxplot') + \
         geom_point(aes(color='class'), stat='boxplot') + \
         scale_color_brewer(type='qual', palette='Dark2') + \
         ggtitle('geom_crossbar() + geom_point(): stat="boxplot"') + \
         theme(legend_position='none')

w, h = 400, 300
bunch = GGBunch()
bunch.add_plot(p1, 0, 0, w, h)
bunch.add_plot(p2, w, 0, w, h)
bunch
# Out:
#    <div id="dFYgIc"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0,
# "y":0,
# "width":400,
# "height":300,
# "feature_spec":{
# "data":{
# },
# "mapping":{
# "x":"class",
# "y":"hwy"
# },
# "data_meta":{
# },
# "ggtitle":{
# "text":"geom_boxplot(): stat=\"boxplot\" (default)"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"color",
# "type":"qual",
# "palette":"Dark2",
# "scale_mapper_kind":"color_brewer"
# }],
# "layers":[{
# "geom":"boxplot",
# "mapping":{
# "color":"class"
# },
# "show_legend":false,
# "data_meta":{
# },
# "data":{
# "..middle..":[NaN,NaN,NaN,NaN,27.0,27.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.5,25.0,NaN,23.0,NaN,NaN,NaN,NaN,17.0,NaN,NaN,26.0],
# "..lower..":[NaN,NaN,NaN,NaN,26.0,26.0,NaN,NaN,NaN,NaN,NaN,NaN,NaN,NaN,17.0,24.0,NaN,22.0,NaN,NaN,NaN,NaN,16.0,NaN,NaN,24.5],
# ...
