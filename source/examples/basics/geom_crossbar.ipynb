# %% [markdown]
# # geom_crossbar()

# %%
import pandas as pd

from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="JgeqmH"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.0.4/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/JetBrains/lets-plot-docs/master/data/mpg.csv')
class_df = df.groupby('class').hwy.agg(['min', 'median', 'max']).reset_index()

# %%
ggplot(class_df, aes(x='class')) + geom_crossbar(aes(ymin='min', middle='median', ymax='max'))
# Out:
#    <div id="b4O0ZG"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "data":{
# "class":["2seater","compact","midsize","minivan","pickup","subcompact","suv"],
# "min":[23.0,23.0,23.0,17.0,12.0,20.0,12.0],
# "median":[25.0,27.0,27.0,23.0,17.0,26.0,17.5],
# "max":[26.0,44.0,32.0,24.0,22.0,44.0,27.0]
# },
# "mapping":{
# "x":"class"
# },
# "data_meta":{
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"crossbar",
# "mapping":{
# "ymin":"min",
# "middle":"median",
# "ymax":"max"
# },
# "data_meta":{
# },
# "data":{
# }
# }]
# };
#            var plotContainer = document.getElementById("b4O0ZG");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
