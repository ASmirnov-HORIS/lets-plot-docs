# %% [markdown]
# # Image Matrix
#
# The `image_matrix()` function arranges a set of images in a grid.

# %%
from PIL import Image
import numpy as np

from lets_plot import *
from lets_plot.bistro.im import *

LetsPlot.setup_html()
# Out:
#             <div id="01oeb4"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v2.0.4/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("01oeb4").appendChild(div);
#                     };
#                     var e = document.getElementById("01oeb4");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
img = Image.open('rock_formation.png')

# %%
rows, cols = 3, 3
matrix = np.empty((rows, cols), dtype=object)
for r in range(rows):
    for c in range(cols):
        w, h = 128 + 64 * c, 128 + 64 * r
        matrix[r][c] = np.asarray(img.resize((w, h)))
image_matrix(matrix, norm=False, scale=.5)
# Out:
#    <div id="zHC7Km"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#        (function() {
#            var plotSpec={
# "kind":"ggbunch",
# "items":[{
# "x":0.0,
# "y":0.0,
# "width":74.0,
# "height":74.0,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# "xmin":"xmin",
# "ymin":"ymin",
# "xmax":"xmax",
# "ymax":"ymax"
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "data":{
# "xmin":[-0.5],
# "ymin":[-0.5],
# "xmax":[127.5],
# "ymax":[127.5]
# }
# }]
# }
# },{
# "x":138.0,
# "y":0.0,
# "width":106.0,
# "height":74.0,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# "xmin":"xmin",
# "ymin":"ymin",
# "xmax":"xmax",
# "ymax":"ymax"
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "data":{
# "xmin":[-0.5],
# "ymin":[-0.5],
# "xmax":[191.5],
# "ymax":[127.5]
# }
# }]
# }
# },{
# "x":276.0,
# "y":0.0,
# "width":138.0,
# "height":74.0,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# "xmin":"xmin",
# "ymin":"ymin",
# "xmax":"xmax",
# "ymax":"ymax"
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "data":{
# "xmin":[-0.5],
# "ymin":[-0.5],
# "xmax":[255.5],
# "ymax":[127.5]
# }
# }]
# }
# },{
# "x":0.0,
# "y":138.0,
# "width":74.0,
# "height":106.0,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# "xmin":"xmin",
# "ymin":"ymin",
# "xmax":"xmax",
# "ymax":"ymax"
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "data":{
# "xmin":[-0.5],
# "ymin":[-0.5],
# "xmax":[127.5],
# "ymax":[191.5]
# }
# }]
# }
# },{
# "x":138.0,
# "y":138.0,
# "width":106.0,
# "height":106.0,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# "xmin":"xmin",
# "ymin":"ymin",
# "xmax":"xmax",
# "ymax":"ymax"
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "data":{
# "xmin":[-0.5],
# "ymin":[-0.5],
# "xmax":[191.5],
# "ymax":[191.5]
# }
# }]
# }
# },{
# "x":276.0,
# "y":138.0,
# "width":138.0,
# "height":106.0,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# "xmin":"xmin",
# "ymin":"ymin",
# "xmax":"xmax",
# "ymax":"ymax"
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "data":{
# "xmin":[-0.5],
# "ymin":[-0.5],
# "xmax":[255.5],
# "ymax":[191.5]
# }
# }]
# }
# },{
# "x":0.0,
# "y":276.0,
# "width":74.0,
# "height":138.0,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# "xmin":"xmin",
# "ymin":"ymin",
# "xmax":"xmax",
# "ymax":"ymax"
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "data":{
# "xmin":[-0.5],
# "ymin":[-0.5],
# "xmax":[127.5],
# "ymax":[255.5]
# }
# }]
# }
# },{
# "x":138.0,
# "y":276.0,
# "width":106.0,
# "height":138.0,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# "xmin":"xmin",
# "ymin":"ymin",
# "xmax":"xmax",
# "ymax":"ymax"
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "data":{
# "xmin":[-0.5],
# "ymin":[-0.5],
# "xmax":[191.5],
# "ymax":[255.5]
# }
# }]
# }
# },{
# "x":276.0,
# "y":276.0,
# "width":138.0,
# "height":138.0,
# "feature_spec":{
# "mapping":{
# },
# "data_meta":{
# },
# "theme":{
# "axis_title":"blank",
# "axis_text":"blank",
# "axis_ticks":"blank",
# "axis_line":"blank"
# },
# "kind":"plot",
# "scales":[{
# "aesthetic":"x",
# "expand":[0,0]
# },{
# "aesthetic":"y",
# "expand":[0,0]
# }],
# "layers":[{
# "geom":"image",
# "mapping":{
# "xmin":"xmin",
# "ymin":"ymin",
# "xmax":"xmax",
# "ymax":"ymax"
# },
# "data_meta":{
# },
# "href":"data:image/png;base64,...",
# "data":{
# "xmin":[-0.5],
# "ymin":[-0.5],
# "xmax":[255.5],
# "ymax":[255.5]
# }
# }]
# }
# }]
# };
#            var plotContainer = document.getElementById("zHC7Km");
#            window.letsPlotCall(function() {{
#                LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer);
#            }});
#        })();
#    </script>
